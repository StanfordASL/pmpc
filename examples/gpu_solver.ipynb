# %% [markdown]
# # Setup - GPU Solver Examples

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
import sys, sys
from pathlib import Path
import matplotlib.pyplot as plt, numpy as np
from jfi import jaxm

root_path = Path("").absolute().parent
if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))
import pmpc
from pmpc.experimental import scp_solve, solve_problems

# %% [markdown]
# ### Define dynamics

# %%
def car(x, u, p):
    """
    unicycle car dynamics, 4 states, 2 actions
    x1: position x
    x2: position y
    x3: speed (local frame)
    x4: orientation angle

    u1: acceleration
    u2: turning speed (independent of velocity)
    """
    assert x.shape[-1] == 4 and u.shape[-1] == 2
    v_scale, w_scale, T = p[..., 0], p[..., 1], p[..., 2]
    eps = 1e-3
    u1, u2 = v_scale * u[..., 0], w_scale * -u[..., 1]
    u1 = u1 + jaxm.where(u1 >= 0.0, eps, -eps)
    u2 = u2 + jaxm.where(u2 >= 0.0, eps, -eps)

    x0, y0, v0, th0 = x[..., 0], x[..., 1], x[..., 2], x[..., 3]
    xp1 = (
        x0
        + (
            u2 * jaxm.sin(T * u2 + th0) * v0
            + T * u1 * u2 * jaxm.sin(T * u2 + th0)
            + u1 * jaxm.cos(T * u2 + th0)
        )
        / u2**2
        - (jaxm.sin(th0) * u2 * v0 + jaxm.cos(th0) * u1) / u2**2
    )
    xp2 = (
        y0
        - (
            u2 * jaxm.cos(T * u2 + th0) * v0
            - u1 * jaxm.sin(T * u2 + th0)
            + T * u1 * u2 * jaxm.cos(T * u2 + th0)
        )
        / u2**2
        + (jaxm.cos(th0) * u2 * v0 - jaxm.sin(th0) * u1) / u2**2
    )
    xp3 = v0 + T * u1
    xp4 = T * u2 + th0
    xp = jaxm.stack([xp1, xp2, xp3, xp4], -1)
    return xp


def fx_(x, u, p):
    sum_dims = range(0, x.ndim - 1)
    return jaxm.moveaxis(jaxm.jacobian(lambda x: jaxm.sum(car(x, u, p), sum_dims))(x), 0, -2)


def fu_(x, u, p):
    sum_dims = range(0, x.ndim - 1)
    return jaxm.moveaxis(jaxm.jacobian(lambda u: jaxm.sum(car(x, u, p), sum_dims))(u), 0, -2)


@jaxm.jit
def f_fx_fu_fn(x, u):
    p = jaxm.to(jaxm.array([1.0, 1.0, 0.3]), dtype=x.dtype)
    return car(x, u, p), fx_(x, u, p), fu_(x, u, p)
    
SMOOTH_ALPHA = 1e2 # smooth constraints refinement parameter, higher is closer to hard constraints

# %% [markdown]
# ---
# # Specify the problem as a list of problems

# %%
N, xdim, udim = 20, 4, 2

Q = np.tile(np.eye(xdim), (N, 1, 1))
R = np.tile(1e-2 * np.eye(udim), (N, 1, 1))
x0 = np.tile(np.ones(xdim), (1,))
X_ref, U_ref = np.zeros((N, xdim)), np.zeros((N, udim))
X_prev, U_prev = np.zeros((N, xdim)), np.zeros((N, udim))
u_lim = 1.0
u_l, u_u = -u_lim * np.ones((N, udim)), u_lim * np.ones((N, udim))

opts = dict(verbose=True, u_l=u_l, u_u=u_u, reg_x=1e1, reg_u=1e0, max_it=50)
# WE ARE USING GPU HERE ############################################################################
opts["device"] = "cuda"
opts["solver_settings"] = dict(smooth_alpha=SMOOTH_ALPHA)  # GPU supports only smooth constraints
# WE ARE USING GPU HERE ############################################################################
problem = dict(f_fx_fu_fn=f_fx_fu_fn, Q=Q, R=R, x0=x0)
problem = dict(problem, X_ref=X_ref, U_ref=U_ref, X_prev=X_prev, U_prev=U_prev, u_l=u_l, u_u=u_u)
problem = dict(problem, **opts)
M = 1000
# problems = [dict(problem, X_ref=problem["X_ref"] + jaxm.randn((N, xdim))) for _ in range(M)]
problems = [dict(problem, X_ref=problem["X_ref"] + (i != 0) * 1e-1 * jaxm.randn((1, xdim))) for i in range(M)]

# %%
# let's solve the problem
split = False
X, U, data = solve_problems(problems, split=split)
# Out:
# +------+------------+------------+------------+----------+----------+----------+
# |  it  |   elaps    |    obj     |   resid    |  reg_x   |  reg_u   |  alpha   |
# +------+------------+------------+------------+----------+----------+----------+
# | 0001 |  1.384e-01 |  1.038e+01 |  1.864e+00 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0002 |  2.705e-01 |  1.230e+00 |  1.064e+00 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0003 |  3.930e-01 |  1.161e+00 |  1.038e+00 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0004 |  5.172e-01 |  9.950e-01 |  7.175e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0005 |  6.393e-01 |  9.446e-01 |  6.623e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0006 |  7.615e-01 |  9.098e-01 |  4.521e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0007 |  8.839e-01 |  8.825e-01 |  5.300e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0008 |  1.006e+00 |  8.601e-01 |  5.989e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0009 |  1.133e+00 |  8.417e-01 |  6.364e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0010 |  1.257e+00 |  8.255e-01 |  5.867e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0011 |  1.380e+00 |  8.122e-01 |  5.577e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0012 |  1.504e+00 |  8.010e-01 |  3.972e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0013 |  1.627e+00 |  7.918e-01 |  4.048e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0014 |  1.749e+00 |  7.841e-01 |  4.395e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0015 |  1.872e+00 |  7.773e-01 |  4.430e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0016 |  1.995e+00 |  7.721e-01 |  4.006e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0017 |  2.117e+00 |  7.678e-01 |  3.922e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0018 |  2.243e+00 |  7.639e-01 |  3.756e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0019 |  2.366e+00 |  7.606e-01 |  4.198e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0020 |  2.490e+00 |  7.581e-01 |  3.685e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0021 |  2.614e+00 |  7.558e-01 |  5.427e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0022 |  2.737e+00 |  7.543e-01 |  6.638e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0023 |  2.862e+00 |  7.527e-01 |  3.271e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0024 |  2.984e+00 |  7.514e-01 |  3.324e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0025 |  3.108e+00 |  7.504e-01 |  3.898e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0026 |  3.233e+00 |  7.493e-01 |  3.811e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0027 |  3.356e+00 |  7.487e-01 |  3.320e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0028 |  3.479e+00 |  7.480e-01 |  2.381e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0029 |  3.602e+00 |  7.475e-01 |  5.387e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0030 |  3.726e+00 |  7.470e-01 |  3.217e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0031 |  3.849e+00 |  7.465e-01 |  3.946e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0032 |  3.972e+00 |  7.463e-01 |  7.366e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0033 |  4.094e+00 |  7.460e-01 |  2.696e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0034 |  4.218e+00 |  7.457e-01 |  3.943e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0035 |  4.344e+00 |  7.454e-01 |  4.343e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0036 |  4.467e+00 |  7.453e-01 |  3.038e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0037 |  4.590e+00 |  7.452e-01 |  3.431e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0038 |  4.713e+00 |  7.451e-01 |  3.047e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0039 |  4.836e+00 |  7.449e-01 |  3.499e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0040 |  4.959e+00 |  7.448e-01 |  3.014e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0041 |  5.082e+00 |  7.446e-01 |  2.834e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0042 |  5.204e+00 |  7.446e-01 |  3.231e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0043 |  5.329e+00 |  7.447e-01 |  3.707e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0044 |  5.452e+00 |  7.445e-01 |  2.866e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0045 |  5.575e+00 |  7.444e-01 |  3.459e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0046 |  5.698e+00 |  7.444e-01 |  1.850e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0047 |  5.823e+00 |  7.444e-01 |  3.061e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0048 |  5.946e+00 |  7.443e-01 |  3.196e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0049 |  6.069e+00 |  7.443e-01 |  2.516e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# | 0050 |  6.192e+00 |  7.443e-01 |  3.353e-01 |  1.0e+01 |  1.0e+00 |  1.0e+02 |
# +------+------------+------------+------------+----------+----------+----------+
# ################################################################################
# Bad solution found, the solution is approximate to a residual: 3.3533e-01
# ################################################################################

# %% [markdown]
# ### Visualize the results

# %%
idx = 2
plt.figure(4356675)
plt.clf()
for r in range(X.shape[-1]):
    plt.plot(X[idx, :, r], label=f"x{r}")
plt.show()
plt.figure(4534534)
plt.clf()
for r in range(U.shape[-1]):
    plt.plot(U[idx, :, r], label=f"u{r}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ---
# # Specify a problem as a batch

# %%
M, N, xdim, udim = 1000, 20, 4, 2

Q = np.tile(np.eye(xdim), (N, 1, 1))
R = np.tile(1e-2 * np.eye(udim), (N, 1, 1))
x0 = np.tile(np.ones(xdim), (1,))
X_ref, U_ref = np.zeros((N, xdim)), np.zeros((N, udim))
X_prev, U_prev = np.zeros((N, xdim)), np.zeros((N, udim))
u_lim = 1.0
u_l, u_u = -u_lim * np.ones((N, udim)), u_lim * np.ones((N, udim))

Q, R, x0, X_ref, U_ref, X_prev, U_prev, u_l, u_u = [
    np.tile(z, (M,) + (1,) * z.ndim) for z in [Q, R, x0, X_ref, U_ref, X_prev, U_prev, u_l, u_u]
]
X_ref = np.stack([problem["X_ref"] for problem in problems], 0)

opts = dict(verbose=True, reg_x=3e0, reg_u=1e0, max_it=50)
# WE ARE USING GPU HERE ############################################################################
opts["device"] = "cuda"
opts["solver_settings"] = dict(smooth_alpha=SMOOTH_ALPHA)  # GPU supports only smooth constraints
# WE ARE USING GPU HERE ############################################################################
args = dict(f_fx_fu_fn=f_fx_fu_fn, Q=Q, R=R, x0=x0)
args = dict(args, X_ref=X_ref, U_ref=U_ref, X_prev=X_prev, U_prev=U_prev, u_l=u_l, u_u=u_u)

# %% [markdown]
# ### Solve the problem

# %%
X, U, data = scp_solve(**args, **opts, return_solhist=True)
# Out:
# +------+------------+------------+------------+----------+----------+----------+
# |  it  |   elaps    |    obj     |   resid    |  reg_x   |  reg_u   |  alpha   |
# +------+------------+------------+------------+----------+----------+----------+
# | 0001 |  2.400e+00 |  3.886e+00 |  1.864e+00 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0002 |  2.541e+00 |  1.126e+00 |  8.947e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0003 |  2.664e+00 |  9.232e-01 |  9.932e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0004 |  2.787e+00 |  8.568e-01 |  1.005e+00 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0005 |  2.913e+00 |  8.124e-01 |  8.489e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0006 |  3.039e+00 |  7.868e-01 |  7.238e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0007 |  3.163e+00 |  7.715e-01 |  6.483e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0008 |  3.287e+00 |  7.622e-01 |  7.442e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0009 |  3.412e+00 |  7.560e-01 |  8.265e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0010 |  3.535e+00 |  7.515e-01 |  9.104e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0011 |  3.658e+00 |  7.492e-01 |  6.369e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0012 |  3.787e+00 |  7.478e-01 |  6.690e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0013 |  3.913e+00 |  7.469e-01 |  8.677e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0014 |  4.037e+00 |  7.462e-01 |  6.316e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0015 |  4.162e+00 |  7.456e-01 |  5.973e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0016 |  4.288e+00 |  7.454e-01 |  6.514e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0017 |  4.415e+00 |  7.454e-01 |  4.452e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0018 |  4.539e+00 |  7.450e-01 |  6.099e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0019 |  4.664e+00 |  7.450e-01 |  4.919e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0020 |  4.789e+00 |  7.447e-01 |  6.838e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0021 |  4.915e+00 |  7.450e-01 |  5.226e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0022 |  5.042e+00 |  7.448e-01 |  4.508e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0023 |  5.168e+00 |  7.446e-01 |  6.526e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0024 |  5.293e+00 |  7.446e-01 |  5.016e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0025 |  5.415e+00 |  7.447e-01 |  5.655e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0026 |  5.539e+00 |  7.447e-01 |  6.175e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0027 |  5.663e+00 |  7.446e-01 |  5.610e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0028 |  5.787e+00 |  7.445e-01 |  5.983e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0029 |  5.912e+00 |  7.446e-01 |  6.441e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0030 |  6.035e+00 |  7.446e-01 |  5.831e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0031 |  6.160e+00 |  7.447e-01 |  5.604e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0032 |  6.285e+00 |  7.444e-01 |  5.673e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0033 |  6.410e+00 |  7.447e-01 |  5.467e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0034 |  6.535e+00 |  7.446e-01 |  6.524e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0035 |  6.660e+00 |  7.446e-01 |  6.281e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0036 |  6.787e+00 |  7.446e-01 |  3.230e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0037 |  6.913e+00 |  7.446e-01 |  4.805e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0038 |  7.038e+00 |  7.447e-01 |  5.161e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0039 |  7.162e+00 |  7.446e-01 |  2.928e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0040 |  7.285e+00 |  7.444e-01 |  6.348e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0041 |  7.409e+00 |  7.447e-01 |  3.995e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0042 |  7.535e+00 |  7.445e-01 |  3.415e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0043 |  7.658e+00 |  7.446e-01 |  5.741e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0044 |  7.782e+00 |  7.446e-01 |  4.292e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0045 |  7.910e+00 |  7.444e-01 |  5.925e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0046 |  8.035e+00 |  7.445e-01 |  4.240e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0047 |  8.159e+00 |  7.446e-01 |  5.022e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0048 |  8.282e+00 |  7.447e-01 |  5.262e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0049 |  8.405e+00 |  7.446e-01 |  5.201e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0050 |  8.528e+00 |  7.447e-01 |  3.949e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# +------+------------+------------+------------+----------+----------+----------+
# ################################################################################
# Bad solution found, the solution is approximate to a residual: 3.9491e-01
# ################################################################################

# %% [markdown]
# ### Visualize the results

# %%
idx = 2
plt.figure(4356675)
plt.clf()
for r in range(X.shape[-1]):
    plt.plot(X[idx, :, r], label=f"x{r}")
plt.show()
plt.figure(4534534)
plt.clf()
for r in range(U.shape[-1]):
    plt.plot(U[idx, :, r], label=f"u{r}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # CPU version for a quick check

# %%
opts["solver_settings"] = dict(smooth_alpha=SMOOTH_ALPHA)
# select only the first problem from the batch arguments
cpu_args = {
    k: v[0, ...] if hasattr(v, "shape") and len(v.shape) > 0 else v
    for k, v in args.items()
    if k in set.union(pmpc.SOLVE_KWS, {"Q", "R", "x0", "f_fx_fu_fn"})
}
cpu_opts = {k: v for k, v in opts.items() if k in pmpc.SOLVE_KWS}

# %%
X2, U2, data = pmpc.solve(**cpu_args, **cpu_opts)
# Out:
# +------+------------+------------+------------+------------+------------+
# |  it  |   elaps    |    obj     |   resid    |   reg_x    |   reg_u    |
# +------+------------+------------+------------+------------+------------+
# | 0001 |  4.368e-03 |  2.206e+00 |  1.944e+00 |  3.000e+00 |  1.000e+00 |
# | 0002 |  7.812e-03 |  1.998e+00 |  3.095e-01 |  3.000e+00 |  1.000e+00 |
# | 0003 |  1.118e-02 |  1.853e+00 |  2.418e-01 |  3.000e+00 |  1.000e+00 |
# | 0004 |  1.443e-02 |  1.761e+00 |  1.301e-01 |  3.000e+00 |  1.000e+00 |
# | 0005 |  1.794e-02 |  1.709e+00 |  1.596e-01 |  3.000e+00 |  1.000e+00 |
# | 0006 |  2.128e-02 |  1.676e+00 |  1.498e-01 |  3.000e+00 |  1.000e+00 |
# | 0007 |  2.501e-02 |  1.655e+00 |  1.365e-01 |  3.000e+00 |  1.000e+00 |
# | 0008 |  2.858e-02 |  1.642e+00 |  1.226e-01 |  3.000e+00 |  1.000e+00 |
# | 0009 |  3.205e-02 |  1.632e+00 |  1.092e-01 |  3.000e+00 |  1.000e+00 |
# | 0010 |  3.490e-02 |  1.626e+00 |  9.693e-02 |  3.000e+00 |  1.000e+00 |
# | 0011 |  3.738e-02 |  1.622e+00 |  8.598e-02 |  3.000e+00 |  1.000e+00 |
# | 0012 |  3.973e-02 |  1.619e+00 |  5.280e-02 |  3.000e+00 |  1.000e+00 |
# | 0013 |  4.205e-02 |  1.617e+00 |  5.010e-02 |  3.000e+00 |  1.000e+00 |
# | 0014 |  4.437e-02 |  1.616e+00 |  4.232e-02 |  3.000e+00 |  1.000e+00 |
# | 0015 |  4.666e-02 |  1.616e+00 |  3.119e-02 |  3.000e+00 |  1.000e+00 |
# | 0016 |  4.896e-02 |  1.616e+00 |  2.845e-02 |  3.000e+00 |  1.000e+00 |
# | 0017 |  5.123e-02 |  1.615e+00 |  2.593e-02 |  3.000e+00 |  1.000e+00 |
# | 0018 |  5.357e-02 |  1.615e+00 |  2.366e-02 |  3.000e+00 |  1.000e+00 |
# | 0019 |  5.587e-02 |  1.615e+00 |  2.158e-02 |  3.000e+00 |  1.000e+00 |
# | 0020 |  5.817e-02 |  1.615e+00 |  1.971e-02 |  3.000e+00 |  1.000e+00 |
# | 0021 |  6.048e-02 |  1.615e+00 |  1.803e-02 |  3.000e+00 |  1.000e+00 |
# | 0022 |  6.272e-02 |  1.614e+00 |  1.652e-02 |  3.000e+00 |  1.000e+00 |
# | 0023 |  6.501e-02 |  1.614e+00 |  1.516e-02 |  3.000e+00 |  1.000e+00 |
# | 0024 |  6.738e-02 |  1.614e+00 |  1.394e-02 |  3.000e+00 |  1.000e+00 |
# | 0025 |  6.970e-02 |  1.614e+00 |  1.284e-02 |  3.000e+00 |  1.000e+00 |
# | 0026 |  7.211e-02 |  1.614e+00 |  1.185e-02 |  3.000e+00 |  1.000e+00 |
# | 0027 |  7.438e-02 |  1.614e+00 |  1.095e-02 |  3.000e+00 |  1.000e+00 |
# | 0028 |  7.666e-02 |  1.614e+00 |  1.014e-02 |  3.000e+00 |  1.000e+00 |
# | 0029 |  7.910e-02 |  1.614e+00 |  9.403e-03 |  3.000e+00 |  1.000e+00 |
# | 0030 |  8.143e-02 |  1.614e+00 |  7.690e-03 |  3.000e+00 |  1.000e+00 |
# | 0031 |  8.371e-02 |  1.614e+00 |  8.091e-03 |  3.000e+00 |  1.000e+00 |
# | 0032 |  8.600e-02 |  1.614e+00 |  7.540e-03 |  3.000e+00 |  1.000e+00 |
# | 0033 |  8.831e-02 |  1.614e+00 |  7.036e-03 |  3.000e+00 |  1.000e+00 |
# | 0034 |  9.059e-02 |  1.614e+00 |  6.573e-03 |  3.000e+00 |  1.000e+00 |
# | 0035 |  9.291e-02 |  1.614e+00 |  6.167e-03 |  3.000e+00 |  1.000e+00 |
# | 0036 |  9.526e-02 |  1.614e+00 |  5.741e-03 |  3.000e+00 |  1.000e+00 |
# | 0037 |  9.755e-02 |  1.614e+00 |  5.422e-03 |  3.000e+00 |  1.000e+00 |
# | 0038 |  9.998e-02 |  1.614e+00 |  5.047e-03 |  3.000e+00 |  1.000e+00 |
# | 0039 |  1.023e-01 |  1.614e+00 |  4.794e-03 |  3.000e+00 |  1.000e+00 |
# | 0040 |  1.045e-01 |  1.614e+00 |  4.461e-03 |  3.000e+00 |  1.000e+00 |
# | 0041 |  1.069e-01 |  1.614e+00 |  4.226e-03 |  3.000e+00 |  1.000e+00 |
# | 0042 |  1.092e-01 |  1.614e+00 |  3.981e-03 |  3.000e+00 |  1.000e+00 |
# | 0043 |  1.115e-01 |  1.614e+00 |  3.749e-03 |  3.000e+00 |  1.000e+00 |
# | 0044 |  1.138e-01 |  1.614e+00 |  3.557e-03 |  3.000e+00 |  1.000e+00 |
# | 0045 |  1.161e-01 |  1.614e+00 |  3.342e-03 |  3.000e+00 |  1.000e+00 |
# | 0046 |  1.183e-01 |  1.614e+00 |  3.170e-03 |  3.000e+00 |  1.000e+00 |
# | 0047 |  1.209e-01 |  1.614e+00 |  3.000e-03 |  3.000e+00 |  1.000e+00 |
# | 0048 |  1.231e-01 |  1.614e+00 |  2.838e-03 |  3.000e+00 |  1.000e+00 |
# | 0049 |  1.254e-01 |  1.614e+00 |  2.678e-03 |  3.000e+00 |  1.000e+00 |
# | 0050 |  1.277e-01 |  1.614e+00 |  2.565e-03 |  3.000e+00 |  1.000e+00 |
# +------+------------+------------+------------+------------+------------+

# %%
plt.figure(4356675)
plt.clf()
for r in range(X.shape[-1]):
    plt.plot(X2[:, r], label=f"x{r}")
plt.show()
plt.figure(4534534)
plt.clf()
for r in range(U.shape[-1]):
    plt.plot(U2[:, r], label=f"u{r}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
