# %% [markdown]
# # Setup - GPU Solver Examples

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
import sys, sys
from pathlib import Path
import matplotlib.pyplot as plt, numpy as np
from jfi import jaxm

root_path = Path("").absolute().parent
if str(root_path) not in sys.path:
    sys.path.insert(0, str(root_path))
import pmpc
from pmpc.experimental import scp_solve, solve_problems

# %% [markdown]
# ### Define dynamics

# %%
def car(x, u, p):
    """
    unicycle car dynamics, 4 states, 2 actions
    x1: position x
    x2: position y
    x3: speed (local frame)
    x4: orientation angle

    u1: acceleration
    u2: turning speed (independent of velocity)
    """
    assert x.shape[-1] == 4 and u.shape[-1] == 2
    v_scale, w_scale, T = p[..., 0], p[..., 1], p[..., 2]
    eps = 1e-3
    u1, u2 = v_scale * u[..., 0], w_scale * -u[..., 1]
    u1 = u1 + jaxm.where(u1 >= 0.0, eps, -eps)
    u2 = u2 + jaxm.where(u2 >= 0.0, eps, -eps)

    x0, y0, v0, th0 = x[..., 0], x[..., 1], x[..., 2], x[..., 3]
    xp1 = (
        x0
        + (
            u2 * jaxm.sin(T * u2 + th0) * v0
            + T * u1 * u2 * jaxm.sin(T * u2 + th0)
            + u1 * jaxm.cos(T * u2 + th0)
        )
        / u2**2
        - (jaxm.sin(th0) * u2 * v0 + jaxm.cos(th0) * u1) / u2**2
    )
    xp2 = (
        y0
        - (
            u2 * jaxm.cos(T * u2 + th0) * v0
            - u1 * jaxm.sin(T * u2 + th0)
            + T * u1 * u2 * jaxm.cos(T * u2 + th0)
        )
        / u2**2
        + (jaxm.cos(th0) * u2 * v0 - jaxm.sin(th0) * u1) / u2**2
    )
    xp3 = v0 + T * u1
    xp4 = T * u2 + th0
    xp = jaxm.stack([xp1, xp2, xp3, xp4], -1)
    return xp


def fx_(x, u, p):
    sum_dims = range(0, x.ndim - 1)
    return jaxm.moveaxis(jaxm.jacobian(lambda x: jaxm.sum(car(x, u, p), sum_dims))(x), 0, -2)


def fu_(x, u, p):
    sum_dims = range(0, x.ndim - 1)
    return jaxm.moveaxis(jaxm.jacobian(lambda u: jaxm.sum(car(x, u, p), sum_dims))(u), 0, -2)


@jaxm.jit
def f_fx_fu_fn(x, u):
    p = jaxm.to(jaxm.array([1.0, 1.0, 0.3]), dtype=x.dtype)
    return car(x, u, p), fx_(x, u, p), fu_(x, u, p)
    
SMOOTH_ALPHA = 1e2 # smooth constraints refinement parameter, higher is closer to hard constraints

# %% [markdown]
# ---
# # Specify the problem as a list of problems

# %%
N, xdim, udim = 20, 4, 2

Q = np.tile(np.eye(xdim), (N, 1, 1))
R = np.tile(1e-2 * np.eye(udim), (N, 1, 1))
x0 = np.tile(np.ones(xdim), (1,))
X_ref, U_ref = np.zeros((N, xdim)), np.zeros((N, udim))
X_prev, U_prev = np.zeros((N, xdim)), np.zeros((N, udim))
u_lim = 1.0
u_l, u_u = -u_lim * np.ones((N, udim)), u_lim * np.ones((N, udim))

opts = dict(verbose=True, u_l=u_l, u_u=u_u, reg_x=3e0, reg_u=1e0, max_it=50)
# WE ARE USING GPU HERE ############################################################################
opts["device"] = "cuda"
opts["solver_settings"] = dict(smooth_alpha=SMOOTH_ALPHA)  # GPU supports only smooth constraints
# WE ARE USING GPU HERE ############################################################################
problem = dict(f_fx_fu_fn=f_fx_fu_fn, Q=Q, R=R, x0=x0)
problem = dict(problem, X_ref=X_ref, U_ref=U_ref, X_prev=X_prev, U_prev=U_prev, u_l=u_l, u_u=u_u)
problem = dict(problem, **opts)
M = 1000
# problems = [dict(problem, X_ref=problem["X_ref"] + jaxm.randn((N, xdim))) for _ in range(M)]
problems = [dict(problem, X_ref=problem["X_ref"] + (i != 0) * 1e-1 * jaxm.randn((1, xdim))) for i in range(M)]

# %%
# let's solve the problem
split = False
X, U, data = solve_problems(problems, split=split)
# Out:
# +------+------------+------------+------------+----------+----------+----------+
# |  it  |   elaps    |    obj     |   resid    |  reg_x   |  reg_u   |  alpha   |
# +------+------------+------------+------------+----------+----------+----------+
# | 0001 |  5.739e-01 |  3.874e+00 |  1.864e+00 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0002 |  6.915e-01 |  1.115e+00 |  9.985e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0003 |  8.091e-01 |  9.137e-01 |  1.011e+00 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0004 |  9.297e-01 |  8.490e-01 |  9.780e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0005 |  1.051e+00 |  8.051e-01 |  8.339e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0006 |  1.179e+00 |  7.794e-01 |  9.907e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0007 |  1.300e+00 |  7.652e-01 |  6.589e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0008 |  1.421e+00 |  7.552e-01 |  7.343e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0009 |  1.542e+00 |  7.496e-01 |  5.443e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0010 |  1.663e+00 |  7.451e-01 |  8.659e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0011 |  1.792e+00 |  7.422e-01 |  6.921e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0012 |  1.914e+00 |  7.415e-01 |  5.928e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0013 |  2.036e+00 |  7.401e-01 |  5.925e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0014 |  2.159e+00 |  7.401e-01 |  5.177e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0015 |  2.281e+00 |  7.388e-01 |  6.474e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0016 |  2.411e+00 |  7.390e-01 |  4.750e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0017 |  2.533e+00 |  7.383e-01 |  9.751e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0018 |  2.655e+00 |  7.387e-01 |  9.221e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0019 |  2.778e+00 |  7.384e-01 |  6.579e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0020 |  2.906e+00 |  7.383e-01 |  6.572e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0021 |  3.029e+00 |  7.385e-01 |  7.715e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0022 |  3.153e+00 |  7.381e-01 |  4.945e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0023 |  3.275e+00 |  7.383e-01 |  5.693e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0024 |  3.397e+00 |  7.382e-01 |  5.974e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0025 |  3.526e+00 |  7.380e-01 |  6.023e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0026 |  3.648e+00 |  7.382e-01 |  4.334e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0027 |  3.771e+00 |  7.381e-01 |  7.632e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0028 |  3.893e+00 |  7.381e-01 |  5.381e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0029 |  4.015e+00 |  7.382e-01 |  4.345e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0030 |  4.145e+00 |  7.381e-01 |  5.575e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0031 |  4.267e+00 |  7.380e-01 |  5.747e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0032 |  4.390e+00 |  7.381e-01 |  6.031e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0033 |  4.512e+00 |  7.380e-01 |  5.648e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0034 |  4.635e+00 |  7.380e-01 |  4.242e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0035 |  4.766e+00 |  7.381e-01 |  5.135e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0036 |  4.889e+00 |  7.380e-01 |  5.061e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0037 |  5.011e+00 |  7.380e-01 |  5.529e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0038 |  5.134e+00 |  7.382e-01 |  3.438e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0039 |  5.264e+00 |  7.380e-01 |  4.623e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0040 |  5.387e+00 |  7.379e-01 |  4.720e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0041 |  5.510e+00 |  7.382e-01 |  4.767e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0042 |  5.634e+00 |  7.382e-01 |  5.581e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0043 |  5.757e+00 |  7.380e-01 |  5.826e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0044 |  5.887e+00 |  7.380e-01 |  3.477e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0045 |  6.010e+00 |  7.381e-01 |  5.231e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0046 |  6.134e+00 |  7.381e-01 |  4.671e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0047 |  6.257e+00 |  7.380e-01 |  4.546e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0048 |  6.381e+00 |  7.380e-01 |  4.271e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0049 |  6.511e+00 |  7.379e-01 |  5.274e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0050 |  6.635e+00 |  7.381e-01 |  5.752e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# +------+------------+------------+------------+----------+----------+----------+
# ################################################################################
# Bad solution found, the solution is approximate to a residual: 5.7516e-01
# ################################################################################

# %% [markdown]
# ### Visualize the results

# %%
idx = 2
plt.figure(4356675)
plt.clf()
for r in range(X.shape[-1]):
    plt.plot(X[idx, :, r], label=f"x{r}")
plt.show()
plt.figure(4534534)
plt.clf()
for r in range(U.shape[-1]):
    plt.plot(U[idx, :, r], label=f"u{r}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ---
# # Specify a problem as a batch

# %%
M, N, xdim, udim = 1000, 20, 4, 2

Q = np.tile(np.eye(xdim), (N, 1, 1))
R = np.tile(1e-2 * np.eye(udim), (N, 1, 1))
x0 = np.tile(np.ones(xdim), (1,))
X_ref, U_ref = np.zeros((N, xdim)), np.zeros((N, udim))
X_prev, U_prev = np.zeros((N, xdim)), np.zeros((N, udim))
u_lim = 1.0
u_l, u_u = -u_lim * np.ones((N, udim)), u_lim * np.ones((N, udim))

Q, R, x0, X_ref, U_ref, X_prev, U_prev, u_l, u_u = [
    np.tile(z, (M,) + (1,) * z.ndim) for z in [Q, R, x0, X_ref, U_ref, X_prev, U_prev, u_l, u_u]
]

opts = dict(verbose=True, reg_x=3e0, reg_u=1e0, max_it=50)
# WE ARE USING GPU HERE ############################################################################
opts["device"] = "cuda"
opts["solver_settings"] = dict(smooth_alpha=SMOOTH_ALPHA)  # GPU supports only smooth constraints
# WE ARE USING GPU HERE ############################################################################
args = dict(f_fx_fu_fn=f_fx_fu_fn, Q=Q, R=R, x0=x0)
args = dict(args, X_ref=X_ref, U_ref=U_ref, X_prev=X_prev, U_prev=U_prev, u_l=u_l, u_u=u_u)

# %% [markdown]
# ### Solve the problem

# %%
X, U, data = scp_solve(**args, **opts)
# Out:
# +------+------------+------------+------------+----------+----------+----------+
# |  it  |   elaps    |    obj     |   resid    |  reg_x   |  reg_u   |  alpha   |
# +------+------------+------------+------------+----------+----------+----------+
# | 0001 |  1.399e-01 |  3.862e+00 |  1.864e+00 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0002 |  2.704e-01 |  1.106e+00 |  5.491e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0003 |  3.904e-01 |  9.090e-01 |  2.740e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0004 |  5.180e-01 |  8.369e-01 |  2.034e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0005 |  6.359e-01 |  7.955e-01 |  1.398e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0006 |  7.557e-01 |  7.717e-01 |  1.552e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0007 |  8.795e-01 |  7.569e-01 |  1.426e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0008 |  1.002e+00 |  7.440e-01 |  1.877e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0009 |  1.130e+00 |  7.428e-01 |  1.685e-01 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0010 |  1.253e+00 |  7.374e-01 |  9.542e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0011 |  1.376e+00 |  7.347e-01 |  7.491e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0012 |  1.498e+00 |  7.331e-01 |  5.174e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0013 |  1.628e+00 |  7.321e-01 |  2.630e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0014 |  1.750e+00 |  7.316e-01 |  2.784e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0015 |  1.873e+00 |  7.313e-01 |  2.815e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0016 |  1.995e+00 |  7.310e-01 |  2.658e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0017 |  2.125e+00 |  7.309e-01 |  2.409e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0018 |  2.248e+00 |  7.308e-01 |  2.176e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0019 |  2.371e+00 |  7.307e-01 |  1.938e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0020 |  2.495e+00 |  7.306e-01 |  1.755e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0021 |  2.617e+00 |  7.306e-01 |  1.571e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0022 |  2.740e+00 |  7.305e-01 |  1.403e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0023 |  2.869e+00 |  7.305e-01 |  1.270e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0024 |  2.992e+00 |  7.305e-01 |  1.140e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0025 |  3.114e+00 |  7.304e-01 |  1.022e-02 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0026 |  3.236e+00 |  7.304e-01 |  9.140e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0027 |  3.367e+00 |  7.304e-01 |  8.385e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0028 |  3.489e+00 |  7.304e-01 |  7.410e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0029 |  3.611e+00 |  7.304e-01 |  6.850e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0030 |  3.734e+00 |  7.304e-01 |  6.156e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0031 |  3.856e+00 |  7.304e-01 |  5.498e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0032 |  3.985e+00 |  7.304e-01 |  5.124e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0033 |  4.107e+00 |  7.304e-01 |  4.621e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0034 |  4.230e+00 |  7.304e-01 |  4.197e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0035 |  4.351e+00 |  7.304e-01 |  3.617e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0036 |  4.481e+00 |  7.304e-01 |  3.507e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0037 |  4.603e+00 |  7.304e-01 |  3.641e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0038 |  4.725e+00 |  7.304e-01 |  2.337e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0039 |  4.847e+00 |  7.304e-01 |  3.140e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0040 |  4.969e+00 |  7.304e-01 |  2.023e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0041 |  5.091e+00 |  7.304e-01 |  1.898e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0042 |  5.221e+00 |  7.304e-01 |  1.644e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0043 |  5.343e+00 |  7.304e-01 |  2.399e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0044 |  5.466e+00 |  7.304e-01 |  1.734e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0045 |  5.588e+00 |  7.303e-01 |  1.312e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0046 |  5.718e+00 |  7.304e-01 |  8.042e-04 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0047 |  5.842e+00 |  7.303e-01 |  1.071e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0048 |  5.965e+00 |  7.303e-01 |  1.397e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0049 |  6.087e+00 |  7.303e-01 |  1.209e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# | 0050 |  6.210e+00 |  7.303e-01 |  1.245e-03 |  3.0e+00 |  1.0e+00 |  1.0e+02 |
# +------+------------+------------+------------+----------+----------+----------+

# %% [markdown]
# ### Visualize the results

# %%
idx = 2
plt.figure(4356675)
plt.clf()
for r in range(X.shape[-1]):
    plt.plot(X[idx, :, r], label=f"x{r}")
plt.show()
plt.figure(4534534)
plt.clf()
for r in range(U.shape[-1]):
    plt.plot(U[idx, :, r], label=f"u{r}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # CPU version for a quick check

# %%
opts["solver_settings"] = dict(smooth_alpha=SMOOTH_ALPHA)
# select only the first problem from the batch arguments
cpu_args = {
    k: v[0, ...] if hasattr(v, "shape") and len(v.shape) > 0 else v
    for k, v in args.items()
    if k in set.union(pmpc.SOLVE_KWS, {"Q", "R", "x0", "f_fx_fu_fn"})
}
cpu_opts = {k: v for k, v in opts.items() if k in pmpc.SOLVE_KWS}

# %%
X2, U2, data = pmpc.solve(**cpu_args, **cpu_opts)
# Out:
# +------+------------+------------+------------+------------+------------+
# |  it  |   elaps    |    obj     |   resid    |   reg_x    |   reg_u    |
# +------+------------+------------+------------+------------+------------+
# | 0001 |  1.375e-02 |  2.206e+00 |  1.944e+00 |  3.000e+00 |  1.000e+00 |
# | 0002 |  1.797e-02 |  1.998e+00 |  3.095e-01 |  3.000e+00 |  1.000e+00 |
# | 0003 |  2.259e-02 |  1.853e+00 |  2.418e-01 |  3.000e+00 |  1.000e+00 |
# | 0004 |  2.793e-02 |  1.761e+00 |  1.301e-01 |  3.000e+00 |  1.000e+00 |
# | 0005 |  3.198e-02 |  1.709e+00 |  1.596e-01 |  3.000e+00 |  1.000e+00 |
# | 0006 |  3.573e-02 |  1.676e+00 |  1.498e-01 |  3.000e+00 |  1.000e+00 |
# | 0007 |  4.020e-02 |  1.655e+00 |  1.365e-01 |  3.000e+00 |  1.000e+00 |
# | 0008 |  4.366e-02 |  1.642e+00 |  1.226e-01 |  3.000e+00 |  1.000e+00 |
# | 0009 |  4.754e-02 |  1.632e+00 |  1.092e-01 |  3.000e+00 |  1.000e+00 |
# | 0010 |  5.134e-02 |  1.626e+00 |  9.693e-02 |  3.000e+00 |  1.000e+00 |
# | 0011 |  5.524e-02 |  1.622e+00 |  8.598e-02 |  3.000e+00 |  1.000e+00 |
# | 0012 |  5.892e-02 |  1.619e+00 |  5.280e-02 |  3.000e+00 |  1.000e+00 |
# | 0013 |  6.121e-02 |  1.617e+00 |  5.010e-02 |  3.000e+00 |  1.000e+00 |
# | 0014 |  6.369e-02 |  1.616e+00 |  4.232e-02 |  3.000e+00 |  1.000e+00 |
# | 0015 |  6.593e-02 |  1.616e+00 |  3.119e-02 |  3.000e+00 |  1.000e+00 |
# | 0016 |  6.822e-02 |  1.616e+00 |  2.845e-02 |  3.000e+00 |  1.000e+00 |
# | 0017 |  7.055e-02 |  1.615e+00 |  2.593e-02 |  3.000e+00 |  1.000e+00 |
# | 0018 |  7.286e-02 |  1.615e+00 |  2.366e-02 |  3.000e+00 |  1.000e+00 |
# | 0019 |  7.511e-02 |  1.615e+00 |  2.158e-02 |  3.000e+00 |  1.000e+00 |
# | 0020 |  7.743e-02 |  1.615e+00 |  1.971e-02 |  3.000e+00 |  1.000e+00 |
# | 0021 |  7.968e-02 |  1.615e+00 |  1.803e-02 |  3.000e+00 |  1.000e+00 |
# | 0022 |  8.198e-02 |  1.614e+00 |  1.652e-02 |  3.000e+00 |  1.000e+00 |
# | 0023 |  8.480e-02 |  1.614e+00 |  1.516e-02 |  3.000e+00 |  1.000e+00 |
# | 0024 |  8.715e-02 |  1.614e+00 |  1.394e-02 |  3.000e+00 |  1.000e+00 |
# | 0025 |  8.938e-02 |  1.614e+00 |  1.284e-02 |  3.000e+00 |  1.000e+00 |
# | 0026 |  9.166e-02 |  1.614e+00 |  1.185e-02 |  3.000e+00 |  1.000e+00 |
# | 0027 |  9.392e-02 |  1.614e+00 |  1.095e-02 |  3.000e+00 |  1.000e+00 |
# | 0028 |  9.617e-02 |  1.614e+00 |  1.014e-02 |  3.000e+00 |  1.000e+00 |
# | 0029 |  9.845e-02 |  1.614e+00 |  9.403e-03 |  3.000e+00 |  1.000e+00 |
# | 0030 |  1.008e-01 |  1.614e+00 |  7.690e-03 |  3.000e+00 |  1.000e+00 |
# | 0031 |  1.031e-01 |  1.614e+00 |  8.091e-03 |  3.000e+00 |  1.000e+00 |
# | 0032 |  1.053e-01 |  1.614e+00 |  7.540e-03 |  3.000e+00 |  1.000e+00 |
# | 0033 |  1.076e-01 |  1.614e+00 |  7.036e-03 |  3.000e+00 |  1.000e+00 |
# | 0034 |  1.099e-01 |  1.614e+00 |  6.573e-03 |  3.000e+00 |  1.000e+00 |
# | 0035 |  1.124e-01 |  1.614e+00 |  6.167e-03 |  3.000e+00 |  1.000e+00 |
# | 0036 |  1.147e-01 |  1.614e+00 |  5.741e-03 |  3.000e+00 |  1.000e+00 |
# | 0037 |  1.170e-01 |  1.614e+00 |  5.422e-03 |  3.000e+00 |  1.000e+00 |
# | 0038 |  1.193e-01 |  1.614e+00 |  5.047e-03 |  3.000e+00 |  1.000e+00 |
# | 0039 |  1.216e-01 |  1.614e+00 |  4.794e-03 |  3.000e+00 |  1.000e+00 |
# | 0040 |  1.238e-01 |  1.614e+00 |  4.461e-03 |  3.000e+00 |  1.000e+00 |
# | 0041 |  1.261e-01 |  1.614e+00 |  4.226e-03 |  3.000e+00 |  1.000e+00 |
# | 0042 |  1.284e-01 |  1.614e+00 |  3.981e-03 |  3.000e+00 |  1.000e+00 |
# | 0043 |  1.307e-01 |  1.614e+00 |  3.749e-03 |  3.000e+00 |  1.000e+00 |
# | 0044 |  1.329e-01 |  1.614e+00 |  3.557e-03 |  3.000e+00 |  1.000e+00 |
# | 0045 |  1.352e-01 |  1.614e+00 |  3.342e-03 |  3.000e+00 |  1.000e+00 |
# | 0046 |  1.382e-01 |  1.614e+00 |  3.170e-03 |  3.000e+00 |  1.000e+00 |
# | 0047 |  1.405e-01 |  1.614e+00 |  3.000e-03 |  3.000e+00 |  1.000e+00 |
# | 0048 |  1.430e-01 |  1.614e+00 |  2.838e-03 |  3.000e+00 |  1.000e+00 |
# | 0049 |  1.453e-01 |  1.614e+00 |  2.678e-03 |  3.000e+00 |  1.000e+00 |
# | 0050 |  1.476e-01 |  1.614e+00 |  2.565e-03 |  3.000e+00 |  1.000e+00 |
# +------+------------+------------+------------+------------+------------+

# %%
plt.figure(4356675)
plt.clf()
for r in range(X.shape[-1]):
    plt.plot(X2[:, r], label=f"x{r}")
plt.show()
plt.figure(4534534)
plt.clf()
for r in range(U.shape[-1]):
    plt.plot(U2[:, r], label=f"u{r}")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
